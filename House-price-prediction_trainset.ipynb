# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Dataset/Advance-house-price-prediction/train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df.isnull().sum().head(10)
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage     259
# LotArea           0
# Street            0
# Alley          1369
# LotShape          0
# LandContour       0
# Utilities         0
# dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.isnull(), cbar=False)

# %%
print('No. of Rows: ',df.shape[0])
print('No. of Columns: ',df.shape[1])
# Out:
# No. of Rows:  1460
# No. of Columns:  81

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# Dropping the columns Id, Alley, PoolQC, MiscFeature, and Fence

# %%
df.drop(['Id','Alley','PoolQC','MiscFeature','Fence','GarageYrBlt'], axis=1, inplace=True)

# %%
sns.heatmap(df.isnull(), cbar=False)

# %%
df['LotFrontage'] = df['LotFrontage'].fillna(df.LotFrontage.mean())
df['MasVnrArea'] = df['MasVnrArea'].fillna(df.MasVnrArea.mean())

# %%
df['BsmtQual'] = df['BsmtQual'].fillna(df['BsmtQual'].mode()[0])
df['BsmtCond'] = df['BsmtCond'].fillna(df['BsmtCond'].mode()[0])

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
categorical_features = ['MSSubClass', 'MSZoning', 'Street',
       'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
       'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
       'RoofStyle',
       'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
       'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC',
       'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType',
       'GarageFinish', 'GarageQual', 'GarageCond',
       'PavedDrive', 'SaleType',
       'SaleCondition']

# %%
len(categorical_features)
# Out:
# 40

# %%
sns.heatmap(df[categorical_features].isnull(), cbar=False)

# %%
df[categorical_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 40 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   Street         1460 non-null   object
#  3   LotShape       1460 non-null   object
#  4   LandContour    1460 non-null   object
#  5   Utilities      1460 non-null   object
#  6   LotConfig      1460 non-null   object
#  7   LandSlope      1460 non-null   object
#  8   Neighborhood   1460 non-null   object
#  9   Condition1     1460 non-null   object
#  10  Condition2     1460 non-null   object
#  11  BldgType       1460 non-null   object
#  12  HouseStyle     1460 non-null   object
#  13  RoofStyle      1460 non-null   object
#  14  RoofMatl       1460 non-null   object
#  15  Exterior1st    1460 non-null   object
#  16  Exterior2nd    1460 non-null   object
# ...

# %%
missing_val_cols = ['MasVnrType','BsmtExposure','BsmtFinType1','BsmtFinType2','MasVnrType','BsmtFinType2','CentralAir','BsmtFinType2','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond']

# %%
for i in missing_val_cols:
  df[i] = df[i].fillna(df[i].mode()[0])

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df[categorical_features].isnull(), cbar=False)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.isnull(), cbar=False)

# %%
df.shape
# Out:
# (1460, 75)

# %%
df_test = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Dataset/Advance-house-price-prediction/formulated_test.csv')

# %%
df_test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          20       RH         80.0  ...    2010       WD        Normal
# 1          20       RL         81.0  ...    2010       WD        Normal
# 2          60       RL         74.0  ...    2010       WD        Normal
# 3          60       RL         78.0  ...    2010       WD        Normal
# 4         120       RL         43.0  ...    2010       WD        Normal
#
# [5 rows x 74 columns]

# %%
df.shape
# Out:
# (1460, 75)

# %%
df_test.shape
# Out:
# (1459, 74)

# %%
df_final = pd.concat([df,df_test], axis=0)

# %%
df_final
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# 0             60       RL         65.0  ...        WD        Normal  208500.0
# 1             20       RL         80.0  ...        WD        Normal  181500.0
# 2             60       RL         68.0  ...        WD        Normal  223500.0
# 3             70       RL         60.0  ...        WD       Abnorml  140000.0
# 4             60       RL         84.0  ...        WD        Normal  250000.0
# ...          ...      ...          ...  ...       ...           ...       ...
# 1454         160       RM         21.0  ...        WD        Normal       NaN
# 1455         160       RM         21.0  ...        WD       Abnorml       NaN
# 1456          20       RL        160.0  ...        WD       Abnorml       NaN
# 1457          85       RL         62.0  ...        WD        Normal       NaN
# 1458          60       RL         74.0  ...        WD        Normal       NaN
#
# [2919 rows x 75 columns]

# %%
def encoder(categorical_columns):
  df_new = final_df.copy()
  for col in categorical_columns:
    df1 = pd.get_dummies(df_new[col])
    df_new.drop([col], axis=1, inplace=True)
    df_new = pd.concat([df_new, df1], axis=1)
  return df_new

# %%
final_df = df_final.copy()
df_coded = encoder(categorical_features)

# %%
df_coded.head()
# Out:
#    LotFrontage  LotArea  OverallQual  ...  Family  Normal  Partial
# 0         65.0     8450            7  ...       0       1        0
# 1         80.0     9600            6  ...       0       1        0
# 2         68.0    11250            7  ...       0       1        0
# 3         60.0     9550            7  ...       0       0        0
# 4         84.0    14260            8  ...       0       1        0
#
# [5 rows x 290 columns]

# %%
df_coded.shape
# Out:
# (2919, 290)

# %%
df_coded = df_coded.loc[:, ~df_coded.columns.duplicated()]

# %%
df_coded.shape
# Out:
# (2919, 218)

# %%
df_1 = df_coded.iloc[:1460,:]
df_2 = df_coded.iloc[1460:,:]

# %%
train_x = df_1.drop(['SalePrice'], axis=1)
train_y = df_1['SalePrice']
test_x = df_2.drop(['SalePrice'], axis=1)
test_y = df_2['SalePrice']

# %%
import xgboost
clf = xgboost.XGBRegressor()
clf.fit(train_x, t)
